# %% [markdown]
# #### House Prices Dataset
# #### link: https://www.kaggle.com/c/house-prices-prediction-advanced-regression-techniques/data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'data.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
print(df.shape)
# Out:
# (1460, 81)

# %% [markdown]
# ## Feature Engineering

# %%
# Drop irrelevant columns

df.drop(columns=['Id'],errors='ignore', inplace=True)

# %%
df.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
#
# [1 rows x 80 columns]

# %% [markdown]
# ## Handling Missing Values

# %%
#Check missing values count
missingvalues = df.isnull().sum()
missingvalues = missingvalues[missingvalues > 0].sort_values(ascending=False)
print(missingvalues)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# Percentage of TRUE in Total Values
missing_percentage = df.isnull().mean().sort_values(ascending=False)
print(missing_percentage)
# Out:
# PoolQC         0.995205
# MiscFeature    0.963014
# Alley          0.937671
# Fence          0.807534
# MasVnrType     0.597260
#                  ...
# Heating        0.000000
# HeatingQC      0.000000
# MSZoning       0.000000
# 1stFlrSF       0.000000
# SalePrice      0.000000
# Length: 80, dtype: float64

# %%
# Drop columns with too many missing values
threshold = 0.65
columns_with_high_null_values = missing_percentage[missing_percentage > threshold].index.tolist()
print(columns_with_high_null_values)
# Out:
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence']

# %%
df_1 = df.drop(columns=columns_with_high_null_values, errors='ignore')

# %%
df_1.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='str')

# %%
df_1.shape
# Out:
# (1460, 76)

# %%
import numpy as np

# %%
# Filter by Importance
# (Correlation with salePrice)

target_correlation = df_1.select_dtypes(include=[np.number]).corr()['SalePrice'].abs()
low_impact_threshold = 0.1    # any feature with correlation less than this will be considered low impact
low_impact_features = target_correlation[target_correlation < low_impact_threshold].index.tolist()
print(low_impact_features)
# Out:
# ['MSSubClass', 'OverallCond', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', '3SsnPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
df_2 = df_1.drop(columns=low_impact_features, errors='ignore')

# %%
df_2.shape
# Out:
# (1460, 66)

# %%
# Removing multi-collinearity
correlation_matrix = df_2.select_dtypes(include=[np.number]).corr().abs()
upper_triangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
redundant_features = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.8)]
print(redundant_features)
# Out:
# ['1stFlrSF', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea']

# %%
df_3 = df_2.drop(columns=redundant_features, errors='ignore')

# %%
df_3.shape
# Out:
# (1460, 62)

# %%
df_3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   str
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   str
#  4   LotShape       1460 non-null   str
#  5   LandContour    1460 non-null   str
#  6   Utilities      1460 non-null   str
#  7   LotConfig      1460 non-null   str
#  8   LandSlope      1460 non-null   str
#  9   Neighborhood   1460 non-null   str
#  10  Condition1     1460 non-null   str
#  11  Condition2     1460 non-null   str
#  12  BldgType       1460 non-null   str
#  13  HouseStyle     1460 non-null   str
#  14  OverallQual    1460 non-null   int64
#  15  YearBuilt      1460 non-null   int64
#  16  YearRemodAdd   1460 non-null   int64
#  17  RoofStyle      1460 non-null   str
#  18  RoofMatl       1460 non-null   str
#  19  Exterior1st    1460 non-null   str
#  20  Exterior2nd    1460 non-null   str
#  21  MasVnrType     588 non-null    str
#  22  MasVnrArea     1452 non-null   float64
#  23  ExterQual      1460 non-null   str
#  24  ExterCond      1460 non-null   str
#  25  Foundation     1460 non-null   str
#  26  BsmtQual       1423 non-null   str
#  27  BsmtCond       1423 non-null   str
#  28  BsmtExposure   1422 non-null   str
#  29  BsmtFinType1   1423 non-null   str
#  30  BsmtFinSF1     1460 non-null   int64
#  31  BsmtFinType2   1422 non-null   str
#  32  BsmtUnfSF      1460 non-null   int64
#  33  TotalBsmtSF    1460 non-null   int64
#  34  Heating        1460 non-null   str
#  35  HeatingQC      1460 non-null   str
#  36  CentralAir     1460 non-null   str
#  37  Electrical     1459 non-null   str
#  38  2ndFlrSF       1460 non-null   int64
#  39  GrLivArea      1460 non-null   int64
#  40  BsmtFullBath   1460 non-null   int64
#  41  FullBath       1460 non-null   int64
#  42  HalfBath       1460 non-null   int64
#  43  BedroomAbvGr   1460 non-null   int64
#  44  KitchenAbvGr   1460 non-null   int64
#  45  KitchenQual    1460 non-null   str
#  46  Functional     1460 non-null   str
#  47  Fireplaces     1460 non-null   int64
#  48  FireplaceQu    770 non-null    str
#  49  GarageType     1379 non-null   str
#  50  GarageFinish   1379 non-null   str
#  51  GarageCars     1460 non-null   int64
#  52  GarageQual     1379 non-null   str
#  53  GarageCond     1379 non-null   str
#  54  PavedDrive     1460 non-null   str
#  55  WoodDeckSF     1460 non-null   int64
#  56  OpenPorchSF    1460 non-null   int64
#  57  EnclosedPorch  1460 non-null   int64
#  58  ScreenPorch    1460 non-null   int64
#  59  SaleType       1460 non-null   str
#  60  SaleCondition  1460 non-null   str
#  61  SalePrice      1460 non-null   int64
# dtypes: float64(2), int64(21), str(39)
# memory usage: 707.3 KB

# %%
missing_values = df_3.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

# %%
missing_values
# Out:
# MasVnrType      872
# FireplaceQu     690
# LotFrontage     259
# GarageType       81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# BsmtExposure     38
# BsmtFinType2     38
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
# MasVnrArea        8
# Electrical        1
# dtype: int64

# %%
# Simple Imputation

""" Instead of deleting, we fill the missing values with estimates:
    Mean Imputation(Numerical Data)
    Median Imputation (Numerical Data)
    Mode Imputation (Categorical Data)
"""
# Out:
# ' Instead of deleting, we fill the missing values with estimates:\n    Mean Imputation(Numerical Data)\n    Median Imputation (Numerical Data)\n    Mode Imputation (Categorical Data)\n'

# %%
# a.) Mean Imputation
# LotFrontage
# Pull distribution towards the mean --> underestimates variance

df_3['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df_mean = df_3.copy()
df_mean.fillna({"LotFrontage": df_mean["LotFrontage"].mean()}, inplace=True)
# Out:
#      MSZoning  LotFrontage  LotArea Street LotShape LandContour Utilities  \
# 0          RL         65.0     8450   Pave      Reg         Lvl    AllPub
# 1          RL         80.0     9600   Pave      Reg         Lvl    AllPub
# 2          RL         68.0    11250   Pave      IR1         Lvl    AllPub
# 3          RL         60.0     9550   Pave      IR1         Lvl    AllPub
# 4          RL         84.0    14260   Pave      IR1         Lvl    AllPub
# ...       ...          ...      ...    ...      ...         ...       ...
# 1455       RL         62.0     7917   Pave      Reg         Lvl    AllPub
# 1456       RL         85.0    13175   Pave      Reg         Lvl    AllPub
# 1457       RL         66.0     9042   Pave      Reg         Lvl    AllPub
# 1458       RL         68.0     9717   Pave      Reg         Lvl    AllPub
# 1459       RL         75.0     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive  \
# 0       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 1          FR2       Gtl      Veenker  ...         TA         TA          Y
# 2       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 3       Corner       Gtl      Crawfor  ...         TA         TA          Y
# 4          FR2       Gtl      NoRidge  ...         TA         TA          Y
# ...        ...       ...          ...  ...        ...        ...        ...
# 1455    Inside       Gtl      Gilbert  ...         TA         TA          Y
# 1456    Inside       Gtl       NWAmes  ...         TA         TA          Y
# 1457    Inside       Gtl      Crawfor  ...         TA         TA          Y
# 1458    Inside       Gtl        NAmes  ...         TA         TA          Y
# 1459    Inside       Gtl      Edwards  ...         TA         TA          Y
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch SaleType  \
# 0             0           61              0            0       WD
# 1           298            0              0            0       WD
# 2             0           42              0            0       WD
# 3             0           35            272            0       WD
# 4           192           84              0            0       WD
# ...         ...          ...            ...          ...      ...
# 1455          0           40              0            0       WD
# 1456        349            0              0            0       WD
# 1457          0           60              0            0       WD
# 1458        366            0            112            0       WD
# 1459        736           68              0            0       WD
#
#      SaleCondition SalePrice
# 0           Normal    208500
# 1           Normal    181500
# 2           Normal    223500
# 3          Abnorml    140000
# 4           Normal    250000
# ...            ...       ...
# 1455        Normal    175000
# 1456        Normal    210000
# 1457        Normal    266500
# 1458        Normal    142125
# 1459        Normal    147500
#
# [1460 rows x 62 columns]

# %%
# a.) Median Imputation
# LotFrontage
# Robust for outliers

df_median = df_3.copy()
df_median.fillna({"LotFrontage": df_median["LotFrontage"].median()}, inplace=True)
# Out:
#      MSZoning  LotFrontage  LotArea Street LotShape LandContour Utilities  \
# 0          RL         65.0     8450   Pave      Reg         Lvl    AllPub
# 1          RL         80.0     9600   Pave      Reg         Lvl    AllPub
# 2          RL         68.0    11250   Pave      IR1         Lvl    AllPub
# 3          RL         60.0     9550   Pave      IR1         Lvl    AllPub
# 4          RL         84.0    14260   Pave      IR1         Lvl    AllPub
# ...       ...          ...      ...    ...      ...         ...       ...
# 1455       RL         62.0     7917   Pave      Reg         Lvl    AllPub
# 1456       RL         85.0    13175   Pave      Reg         Lvl    AllPub
# 1457       RL         66.0     9042   Pave      Reg         Lvl    AllPub
# 1458       RL         68.0     9717   Pave      Reg         Lvl    AllPub
# 1459       RL         75.0     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive  \
# 0       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 1          FR2       Gtl      Veenker  ...         TA         TA          Y
# 2       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 3       Corner       Gtl      Crawfor  ...         TA         TA          Y
# 4          FR2       Gtl      NoRidge  ...         TA         TA          Y
# ...        ...       ...          ...  ...        ...        ...        ...
# 1455    Inside       Gtl      Gilbert  ...         TA         TA          Y
# 1456    Inside       Gtl       NWAmes  ...         TA         TA          Y
# 1457    Inside       Gtl      Crawfor  ...         TA         TA          Y
# 1458    Inside       Gtl        NAmes  ...         TA         TA          Y
# 1459    Inside       Gtl      Edwards  ...         TA         TA          Y
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch SaleType  \
# 0             0           61              0            0       WD
# 1           298            0              0            0       WD
# 2             0           42              0            0       WD
# 3             0           35            272            0       WD
# 4           192           84              0            0       WD
# ...         ...          ...            ...          ...      ...
# 1455          0           40              0            0       WD
# 1456        349            0              0            0       WD
# 1457          0           60              0            0       WD
# 1458        366            0            112            0       WD
# 1459        736           68              0            0       WD
#
#      SaleCondition SalePrice
# 0           Normal    208500
# 1           Normal    181500
# 2           Normal    223500
# 3          Abnorml    140000
# 4           Normal    250000
# ...            ...       ...
# 1455        Normal    175000
# 1456        Normal    210000
# 1457        Normal    266500
# 1458        Normal    142125
# 1459        Normal    147500
#
# [1460 rows x 62 columns]

# %%
# a.) Mode Imputation
# LotFrontage

df_mode = df_3.copy()

# %%
df_mode['GarageType'].unique()
# Out:
# <StringArray>
# ['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types']
# Length: 7, dtype: str

# %%
df_mode["GarageType"].mode()
# Out:
# 0    Attchd
# Name: GarageType, dtype: str

# %%
df_mode.fillna({"GarageType": df_mode["GarageType"].mode()[0]}, inplace=True)
# Out:
#      MSZoning  LotFrontage  LotArea Street LotShape LandContour Utilities  \
# 0          RL         65.0     8450   Pave      Reg         Lvl    AllPub
# 1          RL         80.0     9600   Pave      Reg         Lvl    AllPub
# 2          RL         68.0    11250   Pave      IR1         Lvl    AllPub
# 3          RL         60.0     9550   Pave      IR1         Lvl    AllPub
# 4          RL         84.0    14260   Pave      IR1         Lvl    AllPub
# ...       ...          ...      ...    ...      ...         ...       ...
# 1455       RL         62.0     7917   Pave      Reg         Lvl    AllPub
# 1456       RL         85.0    13175   Pave      Reg         Lvl    AllPub
# 1457       RL         66.0     9042   Pave      Reg         Lvl    AllPub
# 1458       RL         68.0     9717   Pave      Reg         Lvl    AllPub
# 1459       RL         75.0     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive  \
# 0       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 1          FR2       Gtl      Veenker  ...         TA         TA          Y
# 2       Inside       Gtl      CollgCr  ...         TA         TA          Y
# 3       Corner       Gtl      Crawfor  ...         TA         TA          Y
# 4          FR2       Gtl      NoRidge  ...         TA         TA          Y
# ...        ...       ...          ...  ...        ...        ...        ...
# 1455    Inside       Gtl      Gilbert  ...         TA         TA          Y
# 1456    Inside       Gtl       NWAmes  ...         TA         TA          Y
# 1457    Inside       Gtl      Crawfor  ...         TA         TA          Y
# 1458    Inside       Gtl        NAmes  ...         TA         TA          Y
# 1459    Inside       Gtl      Edwards  ...         TA         TA          Y
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch SaleType  \
# 0             0           61              0            0       WD
# 1           298            0              0            0       WD
# 2             0           42              0            0       WD
# 3             0           35            272            0       WD
# 4           192           84              0            0       WD
# ...         ...          ...            ...          ...      ...
# 1455          0           40              0            0       WD
# 1456        349            0              0            0       WD
# 1457          0           60              0            0       WD
# 1458        366            0            112            0       WD
# 1459        736           68              0            0       WD
#
#      SaleCondition SalePrice
# 0           Normal    208500
# 1           Normal    181500
# 2           Normal    223500
# 3          Abnorml    140000
# 4           Normal    250000
# ...            ...       ...
# 1455        Normal    175000
# 1456        Normal    210000
# 1457        Normal    266500
# 1458        Normal    142125
# 1459        Normal    147500
#
# [1460 rows x 62 columns]

# %% [markdown]
# ## Compare before and after Imputation

# %%
plt.figure(figsize=(10,5))
# kdeplot -> plot taht shows pdf
sns.kdeplot(df["LotFrontage"], label="Original", fill=True)
sns.kdeplot(df_mean["LotFrontage"], label="Mean Imputed", fill=True)
sns.kdeplot(df_median["LotFrontage"], label="Median Imputed", fill=True)
plt.legend()
plt.title("LotFrontage Distribution: Original vs Imputed (Mean/Median)")
plt.show()

# %%
def compare_imputations(df_before, df_after, column_name):
    missing_indices = {column_name: df_before[df_before[column_name].isnull()].index.to_list() for column_name in df_before}

    if column_name not in missing_indices:
        print(f"No missing values were found in column '{column_name}'")
        return
    idx_list = missing_indices[column_name]

    comparison = pd.DataFrame({
        "Before": df_before.loc[idx_list, column_name],
        "After": df_after.loc[idx_list, column_name],
    })

    print(f"Changes in column: {column_name}")
    return comparison

# %% [markdown]
# ## KNN Imputation (K-Nearest Neighbor)  -> ML Algorithm

# %%
from sklearn.impute import KNNImputer

# %%
knn_imputer = KNNImputer(n_neighbors=5)

# %%
df_knn = df_3.copy()

# %%
numerical_cols = df_knn.select_dtypes(include=[np.number]).columns
numerical_cols
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', '2ndFlrSF',
#        'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'ScreenPorch', 'SalePrice'],
#       dtype='str')

# %%
df_knn[numerical_cols] = knn_imputer.fit_transform(df_knn[numerical_cols])

# %%
compare_imputations(df_3, df_knn, 'LotFrontage')
# Out:
# Changes in column: LotFrontage
#       Before  After
# 7        NaN   77.4
# 12       NaN   73.2
# 14       NaN   75.2
# 16       NaN   90.2
# 24       NaN   66.0
# ...      ...    ...
# 1429     NaN   82.2
# 1431     NaN   52.6
# 1441     NaN   34.2
# 1443     NaN   61.0
# 1446     NaN   90.0
#
# [259 rows x 2 columns]

# %%
df_knn[numerical_cols].isnull().sum()
# Out:
# LotFrontage      0
# LotArea          0
# OverallQual      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 2ndFlrSF         0
# GrLivArea        0
# BsmtFullBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# Fireplaces       0
# GarageCars       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# ScreenPorch      0
# SalePrice        0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
# kdeplot -> plot taht shows pdf
sns.kdeplot(df["LotFrontage"], label="Original", fill=True)
sns.kdeplot(df_mean["LotFrontage"], label="Mean Imputed", fill=True)
sns.kdeplot(df_median["LotFrontage"], label="Median Imputed", fill=True)
sns.kdeplot(df_knn["LotFrontage"], label="KNN Imputed", fill=True)
plt.legend()
plt.title("LotFrontage Distribution: Original vs Imputed (Mean/Median/KNN)")
plt.show()

# %% [markdown]
# ## Regression Imputation

# %%
from sklearn.linear_model import LinearRegression

# %%
df_reg = df_3.copy()

# %%
train_data = df_reg.dropna(subset=["LotFrontage"])    # drop the rows where LotFrontage has null values
test_data = df_reg[df_reg["LotFrontage"].isnull()]

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1201 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1201 non-null   str
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1201 non-null   int64
#  3   Street         1201 non-null   str
#  4   LotShape       1201 non-null   str
#  5   LandContour    1201 non-null   str
#  6   Utilities      1201 non-null   str
#  7   LotConfig      1201 non-null   str
#  8   LandSlope      1201 non-null   str
#  9   Neighborhood   1201 non-null   str
#  10  Condition1     1201 non-null   str
#  11  Condition2     1201 non-null   str
#  12  BldgType       1201 non-null   str
#  13  HouseStyle     1201 non-null   str
#  14  OverallQual    1201 non-null   int64
#  15  YearBuilt      1201 non-null   int64
#  16  YearRemodAdd   1201 non-null   int64
#  17  RoofStyle      1201 non-null   str
#  18  RoofMatl       1201 non-null   str
#  19  Exterior1st    1201 non-null   str
#  20  Exterior2nd    1201 non-null   str
#  21  MasVnrType     467 non-null    str
#  22  MasVnrArea     1195 non-null   float64
#  23  ExterQual      1201 non-null   str
#  24  ExterCond      1201 non-null   str
#  25  Foundation     1201 non-null   str
#  26  BsmtQual       1170 non-null   str
#  27  BsmtCond       1170 non-null   str
#  28  BsmtExposure   1169 non-null   str
#  29  BsmtFinType1   1170 non-null   str
#  30  BsmtFinSF1     1201 non-null   int64
#  31  BsmtFinType2   1169 non-null   str
#  32  BsmtUnfSF      1201 non-null   int64
#  33  TotalBsmtSF    1201 non-null   int64
#  34  Heating        1201 non-null   str
#  35  HeatingQC      1201 non-null   str
#  36  CentralAir     1201 non-null   str
#  37  Electrical     1200 non-null   str
#  38  2ndFlrSF       1201 non-null   int64
#  39  GrLivArea      1201 non-null   int64
#  40  BsmtFullBath   1201 non-null   int64
#  41  FullBath       1201 non-null   int64
#  42  HalfBath       1201 non-null   int64
#  43  BedroomAbvGr   1201 non-null   int64
#  44  KitchenAbvGr   1201 non-null   int64
#  45  KitchenQual    1201 non-null   str
#  46  Functional     1201 non-null   str
#  47  Fireplaces     1201 non-null   int64
#  48  FireplaceQu    601 non-null    str
#  49  GarageType     1127 non-null   str
#  50  GarageFinish   1127 non-null   str
#  51  GarageCars     1201 non-null   int64
#  52  GarageQual     1127 non-null   str
#  53  GarageCond     1127 non-null   str
#  54  PavedDrive     1201 non-null   str
#  55  WoodDeckSF     1201 non-null   int64
#  56  OpenPorchSF    1201 non-null   int64
#  57  EnclosedPorch  1201 non-null   int64
#  58  ScreenPorch    1201 non-null   int64
#  59  SaleType       1201 non-null   str
#  60  SaleCondition  1201 non-null   str
#  61  SalePrice      1201 non-null   int64
# dtypes: float64(2), int64(21), str(39)
# memory usage: 591.1 KB

# %%
target_corr_ml = df_reg.select_dtypes(include=[np.number]).corr()['LotFrontage'].abs()

# %%
target_corr_ml
# Out:
# LotFrontage      1.000000
# LotArea          0.426095
# OverallQual      0.251646
# YearBuilt        0.123349
# YearRemodAdd     0.088866
# MasVnrArea       0.193458
# BsmtFinSF1       0.233633
# BsmtUnfSF        0.132644
# TotalBsmtSF      0.392075
# 2ndFlrSF         0.080177
# GrLivArea        0.402797
# BsmtFullBath     0.100949
# FullBath         0.198769
# HalfBath         0.053532
# BedroomAbvGr     0.263170
# KitchenAbvGr     0.006069
# Fireplaces       0.266639
# GarageCars       0.285691
# WoodDeckSF       0.088521
# OpenPorchSF      0.151972
# EnclosedPorch    0.010700
# ScreenPorch      0.041383
# SalePrice        0.351799
# Name: LotFrontage, dtype: float64

# %%
X_train = train_data[["LotArea","OverallQual","TotalBsmtSF","GrLivArea"]]
Y_train = train_data["LotFrontage"]

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([ 8.90135199e-04, -1.49550808e+00,  1.24430130e-02,  1.16904327e-02])

# %%
df_reg.loc[df_reg["LotFrontage"].isnull(), "LotFrontage"] = reg.predict(test_data[["LotArea","OverallQual","TotalBsmtSF","GrLivArea"]])
# Predicting in original dataframe, fill it in LotFrontage

# %%
compare_imputations(df_3, df_reg, "LotFrontage",).head(10)
# Out:
# Changes in column: LotFrontage
#     Before      After
# 7      NaN  76.480215
# 12     NaN  65.575403
# 14     NaN  70.486403
# 16     NaN  64.762909
# 24     NaN  64.943935
# 31     NaN  69.263614
# 42     NaN  60.980342
# 43     NaN  62.848844
# 50     NaN  69.936893
# 64     NaN  74.307034

# %% [markdown]
# ## Filling missing values using Iterative Imputer (MICE)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %%
cols_to_use = ["LotFrontage", "LotArea", "OverallQual", "GrLivArea"]

# %%
df_subset = df_3[cols_to_use].copy()

# %%
itr_imput = IterativeImputer(estimator=LinearRegression(), max_iter=10, random_state=10)

# %%
df_subset_imputed_values = itr_imput.fit_transform(df_subset)

# %%
df_subset[cols_to_use] = df_subset_imputed_values

# %%
df_subset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LotFrontage  1460 non-null   float64
#  1   LotArea      1460 non-null   float64
#  2   OverallQual  1460 non-null   float64
#  3   GrLivArea    1460 non-null   float64
# dtypes: float64(4)
# memory usage: 45.8 KB

# %% [markdown]
# ## Handling Outliers

# %%
df_3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   str
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   str
#  4   LotShape       1460 non-null   str
#  5   LandContour    1460 non-null   str
#  6   Utilities      1460 non-null   str
#  7   LotConfig      1460 non-null   str
#  8   LandSlope      1460 non-null   str
#  9   Neighborhood   1460 non-null   str
#  10  Condition1     1460 non-null   str
#  11  Condition2     1460 non-null   str
#  12  BldgType       1460 non-null   str
#  13  HouseStyle     1460 non-null   str
#  14  OverallQual    1460 non-null   int64
#  15  YearBuilt      1460 non-null   int64
#  16  YearRemodAdd   1460 non-null   int64
#  17  RoofStyle      1460 non-null   str
#  18  RoofMatl       1460 non-null   str
#  19  Exterior1st    1460 non-null   str
#  20  Exterior2nd    1460 non-null   str
#  21  MasVnrType     588 non-null    str
#  22  MasVnrArea     1452 non-null   float64
#  23  ExterQual      1460 non-null   str
#  24  ExterCond      1460 non-null   str
#  25  Foundation     1460 non-null   str
#  26  BsmtQual       1423 non-null   str
#  27  BsmtCond       1423 non-null   str
#  28  BsmtExposure   1422 non-null   str
#  29  BsmtFinType1   1423 non-null   str
#  30  BsmtFinSF1     1460 non-null   int64
#  31  BsmtFinType2   1422 non-null   str
#  32  BsmtUnfSF      1460 non-null   int64
#  33  TotalBsmtSF    1460 non-null   int64
#  34  Heating        1460 non-null   str
#  35  HeatingQC      1460 non-null   str
#  36  CentralAir     1460 non-null   str
#  37  Electrical     1459 non-null   str
#  38  2ndFlrSF       1460 non-null   int64
#  39  GrLivArea      1460 non-null   int64
#  40  BsmtFullBath   1460 non-null   int64
#  41  FullBath       1460 non-null   int64
#  42  HalfBath       1460 non-null   int64
#  43  BedroomAbvGr   1460 non-null   int64
#  44  KitchenAbvGr   1460 non-null   int64
#  45  KitchenQual    1460 non-null   str
#  46  Functional     1460 non-null   str
#  47  Fireplaces     1460 non-null   int64
#  48  FireplaceQu    770 non-null    str
#  49  GarageType     1379 non-null   str
#  50  GarageFinish   1379 non-null   str
#  51  GarageCars     1460 non-null   int64
#  52  GarageQual     1379 non-null   str
#  53  GarageCond     1379 non-null   str
#  54  PavedDrive     1460 non-null   str
#  55  WoodDeckSF     1460 non-null   int64
#  56  OpenPorchSF    1460 non-null   int64
#  57  EnclosedPorch  1460 non-null   int64
#  58  ScreenPorch    1460 non-null   int64
#  59  SaleType       1460 non-null   str
#  60  SaleCondition  1460 non-null   str
#  61  SalePrice      1460 non-null   int64
# dtypes: float64(2), int64(21), str(39)
# memory usage: 707.3 KB

# %%
# Visualizing Outliers
# saleprice(y) needs to be removed outliers first bcz. if it will have extreme data then model will not work

plt.figure(figsize=(8,5))
sns.boxplot(x=df_3["SalePrice"])
plt.title("Boxplot of Sale Price")
plt.show()

# %%
# Scatter plot LotArea vs SalePrice

plt.figure(figsize=(8,5))
sns.scatterplot(x=df_3["LotArea"], y=df_3["SalePrice"])
plt.title("Scatterplot of LotArea vs SalePrice")
plt.show()

# %%
# IQR Method

import numpy

# %%
def detect_outliers(data, col):
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3-q1
    lower_fence = q1 - 1.5*iqr
    upper_fence = q3+1.5*iqr
    outliers = data[(data[col] < lower_fence) | (data[col] > upper_fence)]
    return outliers[col]

# %%
outlier_saleprice = detect_outliers(df_3, "SalePrice")

# %%
print(f"No of outliers in saleprice : {len(outlier_saleprice)}")
# Out:
# No of outliers in saleprice : 61

# %%
# How to check if data is normally distributed

# %%
plt.figure(figsize=(10,5))
# kdeplot -> plot that shows pdf
sns.kdeplot(df_3["SalePrice"], label="df_3", fill=True)
plt.legend()
plt.title("SalePrice Distribution")
plt.show()

# %%
plt.hist(df_3["SalePrice"], bins=10, edgecolor="black")
plt.title("Histogram of Prices")
# Out:
# Text(0.5, 1.0, 'Histogram of Prices')

# %%
# Q-Q Plot

# If data follows a diagonal line, data is normal
import scipy.stats as stats
stats.probplot(df_3['SalePrice'], dist="norm", plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952], shape=(1460,)),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], shape=(1460,))),
#  (np.float64(74160.16474519417),
#   np.float64(180921.19589041095),
#   np.float64(0.9319665641512992)))

# %%
# Shapiro-Wilk Test

alpha = 0.05  # we want to be 95% sure with 0.05(5%) marginal error


# p = ?
""" value < p : data is normal
value > p : data is not normal """

stat, p = stats.shapiro(df["SalePrice"])
print("p-value",p)
if p > alpha:
    print("data looks normal")
else:
    print("data is not normal")
# Out:
# p-value 3.2061412312021656e-33
# data is not normal

# %%
from scipy.stats import zscore

# %%
df["SalePrice_z"] = zscore(df["SalePrice"])
outliers_z = df[(df["SalePrice_z"].abs() > 3)]

# %%
print(f"Number of outliers in SalePrice (Z-Score): {len(outliers_z)}")
outliers_z[["SalePrice","SalePrice_z"]].head()
# Out:
# Number of outliers in SalePrice (Z-Score): 22
#      SalePrice  SalePrice_z
# 58    3.246967     3.246967
# 178   4.040982     4.040982
# 185   3.703050     3.703050
# 349   3.226492     3.226492
# 389   3.086040     3.086040
